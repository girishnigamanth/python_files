# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as pl

jan28=xr.open_dataset('/fs/ess/PFS0220/eurec4a/forcings/eurec4a_20200128.kpt.nc',decode_times=False)
feb2=xr.open_dataset('/fs/ess/PFS0220/eurec4a/forcings/eurec4a_20200202_narenpitak_extended.kpt_inversion.nc',decode_times=False)
feb9=xr.open_dataset('/fs/ess/PFS0220/eurec4a/forcings/eurec4a_20200209.kpt.nc',decode_times=False)
eulerian=xr.open_dataset('/fs/ess/PFS0220/eurec4a/forcings/eurec4a_eulerian_20200202.kpt.nc',decode_times=False)
pl.figure(figsize=(10,6))
jan28.open_sst.plot(label='jan28')
feb2.open_sst.plot(label='feb2')
feb9.open_sst.plot(label='feb9')
eulerian.open_sst.plot(label='eulerian')
pl.legend()

pl.figure(figsize=(10,6))
# Plot the temperature and humidity profiles
jan28.lat.plot(label='jan28')
feb2.lat.plot(label='feb2')
feb9.lat.plot(label='feb9')
eulerian.lat.plot(label='eulerian')
pl.legend()
