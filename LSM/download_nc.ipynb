# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-land',
    {
        'format': 'netcdf',
        'variable': [
            'surface_net_solar_radiation', 'surface_net_thermal_radiation',
            'surface_solar_radiation_downwards', 'surface_thermal_radiation_downwards',
            'leaf_area_index_low_vegetation', 'surface_latent_heat_flux', 'surface_sensible_heat_flux', '2m_temperature'
        ],
        'year': '2017',
        'month': '09',
        'day': [
            '21', '22', '23',
            '24', '25',
        ],
        'time': [
            '00:00', '01:00', '02:00',
            '03:00', '04:00', '05:00',
            '06:00', '07:00', '08:00',
            '09:00', '10:00', '11:00',
            '12:00', '13:00', '14:00',
            '15:00', '16:00', '17:00',
            '18:00', '19:00', '20:00',
            '21:00', '22:00', '23:00',
        ],
        'area': [
            36.75, -97.75, 36.25,
            -97.25,
        ],
    },
    'era_land_SGP_20170921.nc')
# Out:
# 2023-06-28 11:37:55,004 INFO Welcome to the CDS
# 2023-06-28 11:37:55,005 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-land
# 2023-06-28 11:37:55,172 INFO Request is queued
# 2023-06-28 11:37:56,299 INFO Request is running
# 2023-06-28 11:40:47,741 INFO Request is completed
# 2023-06-28 11:40:47,742 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data4/adaptor.mars.internal-1687966831.9898012-792-14-4e8f665f-554b-4da3-8760-aeb3f148b276.nc to era_land_SGP_20170921.nc (71.2K)
# 2023-06-28 11:40:49,950 INFO Download rate 32.2K/s
# Result(content_length=72880,content_type=application/x-netcdf,location=https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data4/adaptor.mars.internal-1687966831.9898012-792-14-4e8f665f-554b-4da3-8760-aeb3f148b276.nc)

# %%
import xarray as xr
import matplotlib.pyplot as pl
import numpy as np

xrdata=xr.open_dataset('/fs/ess/PFS0220/LSM/Jupyter_files/era_land_SGP_20170921.nc',decode_times=True)


pl.figure()
xrdata['lai_lv'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
(xrdata['slhf']/-3600).isel(latitude=1,longitude=1).plot()

pl.figure()
(xrdata['sshf']/-3600).isel(latitude=1,longitude=1).plot()

pl.figure()
(xrdata['t2m']).isel(latitude=1,longitude=1).plot()

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-single-levels',
    {
        'product_type': 'reanalysis',
        'format': 'netcdf',
        'variable': [
            'soil_type', 'surface_net_solar_radiation', 'surface_net_thermal_radiation',
            'surface_solar_radiation_downwards', 'surface_thermal_radiation_downwards', 'type_of_high_vegetation',
            'type_of_low_vegetation', 'high_vegetation_cover', 'low_vegetation_cover', 'convective_rain_rate', 'large_scale_rain_rate',
            'leaf_area_index_low_vegetation', 'leaf_area_index_high_vegetation','surface_latent_heat_flux', 'surface_sensible_heat_flux'
        ],
        'year': '2017',
        'month': '09',
        'day': [
            '21', '22', '23',
            '24', '25',
        ],
        'time': [
            '00:00', '01:00', '02:00',
            '03:00', '04:00', '05:00',
            '06:00', '07:00', '08:00',
            '09:00', '10:00', '11:00',
            '12:00', '13:00', '14:00',
            '15:00', '16:00', '17:00',
            '18:00', '19:00', '20:00',
            '21:00', '22:00', '23:00',
        ],
        'area': [
            34.25, -87.75, 34.5,
            -87.25,
        ],
    },
    'era_single_SEUS_20170921.nc')
# Out:
# 2023-08-04 11:49:26,756 INFO Welcome to the CDS
# 2023-08-04 11:49:26,757 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2023-08-04 11:49:26,900 INFO Request is queued
# 2023-08-04 11:49:28,025 INFO Request is running
# 2023-08-04 11:51:21,589 INFO Request is completed
# 2023-08-04 11:51:21,590 INFO Downloading https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data0/adaptor.mars.internal-1691164240.1796722-23280-14-8bb6848f-3896-4b54-8d00-3c452d611d0a.nc to era_single_SEUS_20170921.nc (26.4K)
# 2023-08-04 11:51:22,221 INFO Download rate 42K/s
# Result(content_length=27076,content_type=application/x-netcdf,location=https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data0/adaptor.mars.internal-1691164240.1796722-23280-14-8bb6848f-3896-4b54-8d00-3c452d611d0a.nc)

# %%
import xarray as xr
import matplotlib.pyplot as pl
import numpy as np

xrdata=xr.open_dataset('/fs/ess/PFS0220/LSM/Jupyter_files/era_single_SEUS_20170921.nc',decode_times=True)

pl.figure()
xrdata['slt'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
xrdata['tvh'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
xrdata['tvl'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
xrdata['cvl'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
xrdata['lai_hv'].isel(time=0,latitude=slice(0,2),longitude=slice(0,2)).plot()

pl.figure()
(xrdata['slhf']/-3600).isel(latitude=1,longitude=1).plot()

pl.figure()
(xrdata['sshf']/-3600).isel(latitude=1,longitude=1).plot()
